# %% [markdown]
# <a href="https://colab.research.google.com/github/reginaldotiete/Dados_CDM/blob/main/Avalia%C3%A7%C3%A3o01_reginaldo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Avaliação 01 –CDM
# # Refaça os gráficos dos experimentos da aula de INS02
# # a) Terra-Agua
# # b) Albedo
# # c) PT100

# %% [markdown]
# # a-Terra-Agua
# # b- Albedo
# # c- PT100

# %%
#Principais bibliotecas

#Aluno: Reginaldo Tiete 

# a. Terra-Agua

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from numpy import genfromtxt
from matplotlib import cm

# %%
uri='https://raw.githubusercontent.com/reginaldotiete/Dados_CDM/main/Reginaldo/CR1000_saida1min.dat'

# %%
#A=pd.read_csv(uri,header=1,skiprows=[2,3]); # Faz a leitura sem  e sem index

# %%
A
# Out:
#                TIMESTAMP  RECORD Tterra_Avg Tagua_Avg  batt_volt_Min  PTemp
# 0    2020-02-14 10:17:00       0      27.66       NAN          12.60  24.07
# 1    2020-02-14 10:18:00       1      29.57     25.18          12.60  24.13
# 2    2020-02-14 10:19:00       2      26.53     27.16          12.60  24.13
# 3    2020-02-14 10:20:00       3      23.95     27.54          12.60  24.16
# 4    2020-02-14 10:21:00       4      23.92     24.03          12.60  24.16
# ..                   ...     ...        ...       ...            ...    ...
# 266  2020-02-21 10:17:00     142      25.54     22.38          12.59  22.92
# 267  2020-02-21 10:18:00     143      25.44     22.33          12.59  22.87
# 268  2020-02-21 10:19:00     144      25.34      22.3          12.58  22.84
# 269  2020-02-21 10:20:00     145      25.19      22.3          12.59  22.81
# 270  2020-02-21 10:21:00     146      25.19     22.05          12.59  22.78
#
# [271 rows x 6 columns]

# %%
A.dtypes
# Out:
# TIMESTAMP         object
# RECORD             int64
# Tterra_Avg        object
# Tagua_Avg         object
# batt_volt_Min    float64
# PTemp            float64
# dtype: object

# %%
plt.plot(np.arange(0,100, step=1),A['Tagua_Avg'][150:250].astype(float));
plt.plot(np.arange(0,100, step=1),A['Tterra_Avg'][150:250].astype(float));

# %%
plt.legend(['Tagua','Tterra']);
plt.title('Gráfico de Experimento - Terra-agua',fontsize=14);

# %%
plt.xlabel('Tempo [min]',fontsize=14)
plt.ylabel('Temperatura [$\circ C$]',fontsize=14)
# Out:
# Text(0, 0.5, 'Temperatura [$\\circ C$]')

# %%
plt.xticks(np.arange(0,110, step=10),fontsize=14);
plt.yticks(np.arange(20,50, step=5),fontsize=14);

# %%
plt.grid()

# %%
# GRAFICO FINAL EXPERIMENTO TERRA-AGUA- Reginaldo.t1

plt.plot(np.arange(0,100, step=1),A['Tagua_Avg'][150:250].astype(float));
plt.plot(np.arange(0,100, step=1),A['Tterra_Avg'][150:250].astype(float));
plt.legend(['Tagua','Tterra']);
plt.title('Gráfico de Experimento - Terra-agua',fontsize=14);
plt.xlabel('Tempo [min]',fontsize=14)
plt.ylabel('Temperatura [$\circ C$]',fontsize=14)
plt.xticks(np.arange(0,110, step=10),fontsize=14);
plt.yticks(np.arange(20,50, step=5),fontsize=14);

plt.grid()

# %%
# b.Albedo

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from numpy import genfromtxt
from matplotlib import cm

# %%
uri='https://raw.githubusercontent.com/reginaldotiete/Dados_CDM/main/Reginaldo/dados_albedo_2020_01-1min'

# %%
A1=pd.read_csv(uri,header=1,skiprows=[2,3]); # Faz a leitura sem  e sem index

# %%
A1
# Out:
#                TIMESTAMP  RECORD Radiacao_Avg Radiacao_Std
# 0    2020-03-13 08:21:00       0        480.4        1.704
# 1    2020-03-13 08:22:00       1        444.8        122.6
# 2    2020-03-13 08:23:00       2          104        10.11
# 3    2020-03-13 08:24:00       3        264.9        200.1
# 4    2020-03-13 08:25:00       4        504.9        1.754
# ..                   ...     ...          ...          ...
# 165  2020-03-13 11:06:00     165       -57.77        7.611
# 166  2020-03-13 11:07:00     166        -83.9        20.83
# 167  2020-03-13 11:08:00     167        -93.6        2.666
# 168  2020-03-13 11:09:00     168       -101.9        3.661
# 169  2020-03-13 11:10:00     169       -110.9         3.92
#
# [170 rows x 4 columns]

# %%
A1.dtypes
# Out:
# TIMESTAMP       object
# RECORD           int64
# Radiacao_Avg    object
# Radiacao_Std    object
# dtype: object

# %%
A1[A1=='NAN']=np.nan

# %%
A1
# Out:
#                TIMESTAMP  RECORD Radiacao_Avg Radiacao_Std
# 0    2020-03-13 08:21:00       0        480.4        1.704
# 1    2020-03-13 08:22:00       1        444.8        122.6
# 2    2020-03-13 08:23:00       2          104        10.11
# 3    2020-03-13 08:24:00       3        264.9        200.1
# 4    2020-03-13 08:25:00       4        504.9        1.754
# ..                   ...     ...          ...          ...
# 165  2020-03-13 11:06:00     165       -57.77        7.611
# 166  2020-03-13 11:07:00     166        -83.9        20.83
# 167  2020-03-13 11:08:00     167        -93.6        2.666
# 168  2020-03-13 11:09:00     168       -101.9        3.661
# 169  2020-03-13 11:10:00     169       -110.9         3.92
#
# [170 rows x 4 columns]

# %%
plt.plot(A1['Radiacao_Avg'][1:100].astype(float));
plt.plot(A1['Radiacao_Std'][1:100].astype(float));

# %%
plt.plot(A1['Radiacao_Avg'][0:100].astype(float));

# %%
plt.legend(['Albedo','5 Superfícies']);
plt.title('Gráfico de Experimento - Albedo',fontsize=14);

# %%
plt.xlabel('Tempo [min]',fontsize=14)
plt.ylabel('Irradiância W/m² [$\circ C$]',fontsize=14)
# Out:
# Text(0, 0.5, 'Irradiância W/m² [$\\circ C$]')

# %%
plt.xticks(np.arange(0,110, step=10),fontsize=14);
plt.yticks(np.arange(0,1100, step=200),fontsize=14);

# %%
plt.plot(A1['Radiacao_Avg'][0:100].astype(float));

plt.legend(['Albedo','5 Superfícies']);
plt.title('Gráfico de Experimento - Albedo',fontsize=14);

plt.xlabel('Tempo [min]',fontsize=14)
plt.ylabel('Irradiância W/m² [$\circ C$]',fontsize=14)

plt.xticks(np.arange(0,110, step=10),fontsize=14);
plt.yticks(np.arange(0,1100, step=200),fontsize=14);

# %%
# PT100

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from numpy import genfromtxt
from matplotlib import cm

# %%
uri='https://raw.githubusercontent.com/reginaldotiete/Dados_CDM/main/Reginaldo/dados_PT100'

# %%
A2=pd.read_csv(uri,header=1,skiprows=[2,3]); # Faz a leitura sem  e sem index

# %%
A2
# Out:
#                TIMESTAMP  RECORD  batt_volt_Min  ...  termopar_Std T108_Std  T_Std
# 0    2019-04-29 10:06:00       0          12.18  ...         2.369    1.087  1.048
# 1    2019-04-29 10:07:00       1          12.18  ...         0.586    0.495  0.922
# 2    2019-04-29 10:08:00       2          12.18  ...         2.212    0.329  0.926
# 3    2019-04-29 10:09:00       3          12.18  ...         0.254    0.407  0.809
# 4    2019-04-29 10:10:00       4          12.18  ...         0.042    0.227  0.864
# ..                   ...     ...            ...  ...           ...      ...    ...
# 235  2019-05-20 09:43:00      45          12.19  ...         0.986    0.638  4.026
# 236  2019-05-20 09:44:00      46          12.19  ...          0.11    0.046  0.132
# 237  2019-05-20 09:45:00      47          12.19  ...         0.074     0.04  3.906
# 238  2019-05-20 09:46:00      48          12.19  ...         0.195    0.075  2.227
# ...

# %%
A2.dtypes
# Out:
# TIMESTAMP         object
# RECORD             int64
# batt_volt_Min    float64
# PTemp            float64
# termopar_Avg      object
# T108_Avg          object
# T_Avg             object
# termopar_Std      object
# T108_Std          object
# T_Std             object
# dtype: object

# %%
A2[A2=='NAN']=np.nan

A2
# Out:
#                TIMESTAMP  RECORD  batt_volt_Min  ...  termopar_Std T108_Std  T_Std
# 0    2019-04-29 10:06:00       0          12.18  ...         2.369    1.087  1.048
# 1    2019-04-29 10:07:00       1          12.18  ...         0.586    0.495  0.922
# 2    2019-04-29 10:08:00       2          12.18  ...         2.212    0.329  0.926
# 3    2019-04-29 10:09:00       3          12.18  ...         0.254    0.407  0.809
# 4    2019-04-29 10:10:00       4          12.18  ...         0.042    0.227  0.864
# ..                   ...     ...            ...  ...           ...      ...    ...
# 235  2019-05-20 09:43:00      45          12.19  ...         0.986    0.638  4.026
# 236  2019-05-20 09:44:00      46          12.19  ...          0.11    0.046  0.132
# 237  2019-05-20 09:45:00      47          12.19  ...         0.074     0.04  3.906
# 238  2019-05-20 09:46:00      48          12.19  ...         0.195    0.075  2.227
# ...

# %%
plt.plot(np.arange(0,10, step=1),A2['T_Avg'][15:25].astype(float));
plt.plot(np.arange(0,10, step=1),A2['T108_Avg'][15:25].astype(float));
plt.plot(np.arange(0,10, step=1),A2['termopar_Avg'][15:25].astype(float));
plt.plot(np.arange(0,10, step=1),A2['termopar_Std'][15:25].astype(float));
plt.plot(np.arange(0,10, step=1),A2['T108_Std'][15:25].astype(float));
plt.plot(np.arange(0,10, step=1),A2['T_Std'][15:25].astype(float));
plt.legend(['T_Avg','T108','termopar_AVG','termopar_Std','T108_Std','T_Std']);

plt.xlabel('Tempo [min]',fontsize=14)
plt.ylabel('Temperatura [$\circ C$]',fontsize=14)


plt.xticks(np.arange(0,100, step=10),fontsize=14);
plt.yticks(np.arange(0,45, step=2),fontsize=14);

# %% [markdown]
# # 2) Baixe os dados de uma radiosonda

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from numpy import genfromtxt

# %%
uri = 'https://raw.githubusercontent.com/reginaldotiete/Dados_CDM/main/Reginaldo/radiosonda_05.csv'
#df=pd.read_csv('radiosonda.csv' ,header=0, delimiter=';') # comando que transforma em dataframe

# %%
df = pd.read_csv(uri,header=0);

# %%
df
# Out:
#       PRES   HGHT  TEMP  DWPT  RELH   MIXR   DRCT   SKNT   THTA   THTE   THTV
# 0   1013.0      3  23.6  22.2    92  16.95   80.0    3.0  295.7  344.5  298.6
# 1   1000.0    112  23.0  20.2    84  15.14   85.0   21.0  296.1  339.9  298.8
# 2    983.0    262  22.6  19.0    80  14.27   80.0   26.0  297.2  338.7  299.7
# 3    964.0    433  22.1  17.6    76  13.33   65.0   24.0  298.4  337.4  300.8
# 4    934.0    710  21.4  15.4    69  11.92   61.0   21.0  300.4  335.6  302.5
# ..     ...    ...   ...   ...   ...    ...    ...    ...    ...    ...    ...
# 91    46.0  21193 -63.1 -88.9     2   0.00   80.0   18.0  506.4  506.4  506.4
# 92    45.0  21329 -62.8 -88.8     2   0.00  110.0   21.0  510.2  510.3  510.2
# 93    42.0  21754 -61.9 -88.6     2   0.00   85.0   27.0  522.5  522.5  522.5
# 94    41.0  21902 -61.6 -88.5     2   0.00   80.0   25.0  526.9  526.9  526.9
# 95    40.6  21962 -61.5 -88.5     2   0.00  528.7  528.7  528.7    NaN    NaN
#
# [96 rows x 11 columns]

# %%
df.columns # comando que mostra o nome das variaveis
# Out:
# Index(['PRES', 'HGHT', 'TEMP', 'DWPT', 'RELH', 'MIXR', 'DRCT', 'SKNT', 'THTA',
#        'THTE', 'THTV'],
#       dtype='object')

# %%
df['DWPT']
# Out:
# 0     22.2
# 1     20.2
# 2     19.0
# 3     17.6
# 4     15.4
#       ...
# 91   -88.9
# 92   -88.8
# 93   -88.6
# 94   -88.5
# 95   -88.5
# Name: DWPT, Length: 96, dtype: float64

# %%
df['TEMP']
# Out:
# 0     23.6
# 1     23.0
# 2     22.6
# 3     22.1
# 4     21.4
#       ...
# 91   -63.1
# 92   -62.8
# 93   -61.9
# 94   -61.6
# 95   -61.5
# Name: TEMP, Length: 96, dtype: float64

# %%
plt.plot(df['TEMP']) # comando plotar grafico

# %%
plt.plot(df['TEMP'],df['HGHT'])

# %%
plt.scatter(df['TEMP'],df['HGHT']) # comando "scatter" grafico pontualmente

# %%
plt.plot(df['DWPT'])
plt.plot(df['TEMP'])

# %%
plt.plot(df['DWPT'],df['HGHT'])
plt.plot(df['TEMP'],df['HGHT'])

# %%
plt.plot(df['HGHT'])

# %%
df['PRES']
# Out:
# 0     1013.0
# 1     1000.0
# 2      983.0
# 3      964.0
# 4      934.0
#        ...
# 91      46.0
# 92      45.0
# 93      42.0
# 94      41.0
# 95      40.6
# Name: PRES, Length: 96, dtype: float64

# %%
plt.plot(df['PRES'])
plt.plot(df['TEMP'])

# %%
df['RELH']
# Out:
# 0     92
# 1     84
# 2     80
# 3     76
# 4     69
#       ..
# 91     2
# 92     2
# 93     2
# 94     2
# 95     2
# Name: RELH, Length: 96, dtype: int64

# %%
plt.plot(df['RELH'])

# %%
df['THTA']
# Out:
# 0     295.7
# 1     296.1
# 2     297.2
# 3     298.4
# 4     300.4
#       ...
# 91    506.4
# 92    510.2
# 93    522.5
# 94    526.9
# 95    528.7
# Name: THTA, Length: 96, dtype: float64

# %%
df['THTE']
# Out:
# 0     344.5
# 1     339.9
# 2     338.7
# 3     337.4
# 4     335.6
#       ...
# 91    506.4
# 92    510.3
# 93    522.5
# 94    526.9
# 95      NaN
# Name: THTE, Length: 96, dtype: float64

# %%
df['THTV']
# Out:
# 0     298.6
# 1     298.8
# 2     299.7
# 3     300.8
# 4     302.5
#       ...
# 91    506.4
# 92    510.2
# 93    522.5
# 94    526.9
# 95      NaN
# Name: THTV, Length: 96, dtype: float64

# %%
df.head(10) # mostra as 10 primeiras linhas
# Out:
#      PRES  HGHT  TEMP  DWPT  RELH   MIXR  DRCT  SKNT   THTA   THTE   THTV
# 0  1013.0     3  23.6  22.2    92  16.95  80.0   3.0  295.7  344.5  298.6
# 1  1000.0   112  23.0  20.2    84  15.14  85.0  21.0  296.1  339.9  298.8
# 2   983.0   262  22.6  19.0    80  14.27  80.0  26.0  297.2  338.7  299.7
# 3   964.0   433  22.1  17.6    76  13.33  65.0  24.0  298.4  337.4  300.8
# 4   934.0   710  21.4  15.4    69  11.92  61.0  21.0  300.4  335.6  302.5
# 5   925.0   794  20.8  14.8    69  11.57  60.0  20.0  300.6  334.8  302.7
# 6   889.0  1136  18.2  14.4    78  11.70  50.0  18.0  301.3  336.0  303.4
# 7   884.0  1184  17.8  14.3    80  11.72  51.0  18.0  301.4  336.2  303.5
# 8   868.0  1341  17.4   7.4    52   7.49  56.0  16.0  302.5  325.2  303.9
# 9   853.0  1489  16.2   7.9    58   7.89  60.0  15.0  302.8  326.7  304.3

# %%
df.tail(10) # mostra as 10 ultimas linhas
# Out:
#     PRES   HGHT  TEMP  DWPT  RELH  MIXR   DRCT   SKNT   THTA   THTE   THTV
# 86  52.0  20441 -64.4 -89.0     2   0.0   70.0   13.0  485.8  485.8  485.8
# 87  51.0  20559 -64.3 -89.0     2   0.0   60.0   18.0  488.9  488.9  488.9
# 88  50.0  20680 -64.1 -89.1     2   0.0   50.0   12.0  492.0  492.0  492.0
# 89  49.0  20804 -63.9 -89.0     2   0.0   90.0    7.0  495.4  495.5  495.5
# 90  47.0  21061 -63.3 -88.9     2   0.0   95.0   12.0  502.6  502.7  502.6
# 91  46.0  21193 -63.1 -88.9     2   0.0   80.0   18.0  506.4  506.4  506.4
# 92  45.0  21329 -62.8 -88.8     2   0.0  110.0   21.0  510.2  510.3  510.2
# 93  42.0  21754 -61.9 -88.6     2   0.0   85.0   27.0  522.5  522.5  522.5
# 94  41.0  21902 -61.6 -88.5     2   0.0   80.0   25.0  526.9  526.9  526.9
# 95  40.6  21962 -61.5 -88.5     2   0.0  528.7  528.7  528.7    NaN    NaN

# %%
df.describe() # faz a estatistica dos dados
# Out:
#               PRES          HGHT       TEMP  ...        THTA        THTE        THTV
# count    96.000000     96.000000  96.000000  ...   96.000000   95.000000   95.000000
# mean    363.376042  10557.260417 -33.936458  ...  362.098958  368.507368  360.834737
# std     297.840905   6712.620039  32.449706  ...   65.506786   57.378318   63.129837
# min      40.600000      3.000000 -68.300000  ...  295.700000  321.000000  298.600000
# 25%     100.750000   4437.250000 -62.825000  ...  314.125000  330.750000  314.300000
# 50%     251.000000  10743.500000 -47.900000  ...  334.350000  336.900000  334.300000
# 75%     595.750000  16435.000000  -2.250000  ...  397.575000  395.650000  395.650000
# max    1013.000000  21962.000000  23.600000  ...  528.700000  526.900000  526.900000
#
# [8 rows x 11 columns]

# %%
df.shape # diz o tamanho da matriz 72 linhas e 11 colunas
# Out:
# (96, 11)

# %%
df.columns
# Out:
# Index(['PRES', 'HGHT', 'TEMP', 'DWPT', 'RELH', 'MIXR', 'DRCT', 'SKNT', 'THTA',
#        'THTE', 'THTV'],
#       dtype='object')

# %%
plt.scatter(df['THTA'],df['HGHT'])

# %%
tp=df['TEMP']

# %%
tk=tp+273

# %%
def converterTCK(x):
    y=x+273
    return y

# %%
converterTCK(df['TEMP'])
# Out:
# 0     296.6
# 1     296.0
# 2     295.6
# 3     295.1
# 4     294.4
#       ...
# 91    209.9
# 92    210.2
# 93    211.1
# 94    211.4
# 95    211.5
# Name: TEMP, Length: 96, dtype: float64

# %%
df['TEMP']
# Out:
# 0     23.6
# 1     23.0
# 2     22.6
# 3     22.1
# 4     21.4
#       ...
# 91   -63.1
# 92   -62.8
# 93   -61.9
# 94   -61.6
# 95   -61.5
# Name: TEMP, Length: 96, dtype: float64

# %%
df['PRES']
# Out:
# 0     1013.0
# 1     1000.0
# 2      983.0
# 3      964.0
# 4      934.0
#        ...
# 91      46.0
# 92      45.0
# 93      42.0
# 94      41.0
# 95      40.6
# Name: PRES, Length: 96, dtype: float64

# %%
TK2= lambda x: x+273
TK2(23)
# Out:
# 296

# %%
tp
# Out:
# 23

# %%
tp=23; po=1013; p=983;

# %%
alt=-(287*TK2(tp)/9.81)*np.log(p/po)

# %%
np.round(alt)
# Out:
# 260.0

# %%
def reduzir(a1,a2,a3):
    y2=a3*np.exp((9.81*a2)/(287*TK2(a1)))
    return y2

# %%
reduzir(25,1008,925)
# Out:
# 1038.3760851288962

# %%
tp=['TEMP']; p1=['PRES']; p2=920

# %%
TK2= lambda x: x+273

# %%
tp=23; po=1013; p=920;

alt=-(287*TK2(tp)/9.81)*np.log(p/po)

# %%
np.round(alt)
# Out:
# 834.0

# %%
def deltaH3(x1,x2,x3,x4):
    yy=-(287*TK2(x1)/x4)*np.log(x2/x3)
    return yy

# %%
deltaH3(tp,p,po,9.81)
# Out:
# 833.9137218587061

# %%
def reduzir(x1,x2,x3):
    y2=x3*np.exp((9.81*x2)/(287*TK2(x1)))
    return y2

reduzir(17,850,920)
# Out:
# 1016.9466139057954

# %%
def deltaH3(x1,x2,x3,x4):
    yy=-((287*TK2(x1))/x4)*np.log(x2/x3)
    return yy

# %%
altitude=df['HGHT']

temp=df['TEMP']
g=df['DRCT']
pressao=df['PRES']*100

# %%
alt2=deltaH3(temp,pressao,1038,g)

# %%
plt.scatter(pressao,altitude)

# %%
plt.scatter(pressao,g)

# %%
rho=pressao/(287*(tp+273.15))

# %%
plt.scatter(df[2:8],df[2:8])

# %%
plt.plot(rho,altitude)

# %%
df
# Out:
#       PRES   HGHT  TEMP  DWPT  RELH   MIXR   DRCT   SKNT   THTA   THTE   THTV
# 0   1013.0      3  23.6  22.2    92  16.95   80.0    3.0  295.7  344.5  298.6
# 1   1000.0    112  23.0  20.2    84  15.14   85.0   21.0  296.1  339.9  298.8
# 2    983.0    262  22.6  19.0    80  14.27   80.0   26.0  297.2  338.7  299.7
# 3    964.0    433  22.1  17.6    76  13.33   65.0   24.0  298.4  337.4  300.8
# 4    934.0    710  21.4  15.4    69  11.92   61.0   21.0  300.4  335.6  302.5
# ..     ...    ...   ...   ...   ...    ...    ...    ...    ...    ...    ...
# 91    46.0  21193 -63.1 -88.9     2   0.00   80.0   18.0  506.4  506.4  506.4
# 92    45.0  21329 -62.8 -88.8     2   0.00  110.0   21.0  510.2  510.3  510.2
# 93    42.0  21754 -61.9 -88.6     2   0.00   85.0   27.0  522.5  522.5  522.5
# 94    41.0  21902 -61.6 -88.5     2   0.00   80.0   25.0  526.9  526.9  526.9
# 95    40.6  21962 -61.5 -88.5     2   0.00  528.7  528.7  528.7    NaN    NaN
#
# [96 rows x 11 columns]

# %%
plt.scatter(rho,altitude)

# %%
plt.scatter(temp,altitude)

# %%
plt.plot(temp, altitude)

# %%
plt.plot(g,altitude)

# %%
plt.scatter(g,altitude)

# %%
TCK=lambda x:x+273.15

# %%
tk3=TCK(df['TEMP'])

# %%
tk3
# Out:
# 0     296.75
# 1     296.15
# 2     295.75
# 3     295.25
# 4     294.55
#        ...
# 91    210.05
# 92    210.35
# 93    211.25
# 94    211.55
# 95    211.65
# Name: TEMP, Length: 96, dtype: float64

# %%
df['TEMP']
# Out:
# 0     23.6
# 1     23.0
# 2     22.6
# 3     22.1
# 4     21.4
#       ...
# 91   -63.1
# 92   -62.8
# 93   -61.9
# 94   -61.6
# 95   -61.5
# Name: TEMP, Length: 96, dtype: float64

# %%
tk3[1:2]
# Out:
# 1    296.15
# Name: TEMP, dtype: float64

# %%
tk3[2:4]
# Out:
# 2    295.75
# 3    295.25
# Name: TEMP, dtype: float64

# %%
tp=25.4;P1=1018;P2=920;

# %%
def deltaH(x1,x2,x3):
    y=-(287*TCK(x1)/9.81)*np.log(x2/x3)
    return y

# %%
alt=deltaH(tp,P2,P1);

# %%
alt
# Out:
# 884.1029706434767

# %%
plt.plot(df['PRES'][0:67])

plt.plot(df['TEMP'][0:67])

# %%
altitude=df['HGHT']
pressao=df['PRES']*100;
tp=df['TEMP'];

# %%
alt2=deltaH(tp,pressao,altitude);
plt.scatter(pressao,altitude)
#plt.plot(pressao,alt2)
plt.xlabel('Pressão [hPa]')
plt.ylabel('Altitude [m]')
# Out:
# Text(0, 0.5, 'Altitude [m]')

# %%
altitude=df['HGHT'];
pressao=df['PRES']*10000;
tp=df['TEMP'];

rho=pressao/(287*(tp+273.15))

plt.scatter(pressao,tp)

# %%
plt.scatter(rho,altitude)

plt.xlabel('Temperatura [°C]')
plt.ylabel('Altitude [m]')
# Out:
# Text(0, 0.5, 'Altitude [m]')

# %%
altitude=df['HGHT']
pressao=df['PRES'];
tp=df['TEMP'];
g=9,8

alt=-(287*TCK(tp)/9.81)*np.log(920/1008)
np.round(alt)
# Out:
# 0     793.0
# 1     791.0
# 2     790.0
# 3     789.0
# 4     787.0
#       ...
# 91    561.0
# 92    562.0
# 93    565.0
# 94    565.0
# 95    566.0
# Name: TEMP, Length: 96, dtype: float64

# %%
plt.plot(alt)

# %%
plt.scatter(tp,altitude)

# %% [markdown]
# # 3) Faça um gráfico do índice ONI que indica a condição de El Nino/La Nina conforme a anomalia de temperatura da tempeatura do superfície do oceano Pacífico.

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from numpy import genfromtxt
from matplotlib import cm

# %%
dd = pd.read_csv('radiosonda.csv',delimiter=';',skiprows=0,dtype=float)

# %%
dd
# Out:
#       PRES     HGHT  TEMP  DWPT   RELH   MIXR   DRCT  SKNT   THTA   THTE   THTV
# 0   1008.0      5.0  25.4  23.8   91.0  18.82  330.0   3.0  297.9  352.7  301.2
# 1   1000.0     77.0  24.6  23.2   92.0  18.28  330.0   7.0  297.8  351.0  301.0
# 2    953.0    500.0  21.2  21.2  100.0  16.94  339.0  15.0  298.4  347.9  301.4
# 3    946.0    564.0  20.9  20.8  100.0  16.68  340.0  16.0  298.8  347.5  301.7
# 4    925.0    759.0  20.0  19.7   98.0  15.88  320.0  20.0  299.8  346.4  302.6
# ..     ...      ...   ...   ...    ...    ...    ...   ...    ...    ...    ...
# 67    41.0  21838.0 -60.5 -83.9    3.0   0.01   65.0  23.0  529.6  529.6  529.6
# 68    38.0  22313.0 -59.5 -84.1    3.0   0.01   60.0  14.0  543.8  543.9  543.8
# 69    35.0  22827.0 -58.4 -84.3    2.0   0.01   95.0  24.0  559.6  559.7  559.6
# 70    33.0  23195.0 -57.6 -84.5    2.0   0.01   90.0  34.0  571.2  571.3  571.2
# 71    32.7  23252.0 -57.5 -84.5    2.0   0.01    NaN   NaN  573.0  573.1  573.0
#
# ...

# %%
plt.plot(A[0:3])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-526-fcbef4b59259> in <module>()
# ----> 1 plt.plot(A[0:3])
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2763         is not None else {}), **kwargs)
#    2764
#    2765
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
#    1649             self.add_line(line)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_base.py in __call__(self, *args, **kwargs)
# ...

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from numpy import genfromtxt
from matplotlib import cm

# %%
A = genfromtxt('TSM.csv',delimiter=';')

# %%
A
# Out:
# array([[       nan,        nan,        nan,        nan,        nan],
#        [ 1.950e+03,  1.000e+00,  2.456e+01,  2.618e+01, -1.620e+00],
#        [ 1.950e+03,  2.000e+00,  2.507e+01,  2.639e+01, -1.320e+00],
#        ...,
#        [ 2.021e+03,  1.000e+00,  2.555e+01,  2.655e+01, -1.000e+00],
#        [ 2.021e+03,  2.000e+00,  2.576e+01,  2.676e+01, -1.000e+00],
#        [ 2.021e+03,  3.000e+00,  2.647e+01,  2.729e+01, -8.200e-01]])

# %%
plt.plot(A[:,3])

# %%
len(A)
# Out:
# 856

# %%
plt.plot(A[:,4])

# %%
dd=np.arange('1950-01', '2020-02', dtype='datetime64[M]')

# %%
plt.plot(A[:,4])
plt.plot.axis=(['1950-01','2020-02'])

# %%
#plt.plot((dd),A)
#plt.plot(A,dd)

# %%
uri='https://raw.githubusercontent.com/reginaldotiete/Dados_CDM/main/Reginaldo/el_nino.txt'

# %%
A = genfromtxt(uri)

# %%
dd=np.arange('1950-01', '2020-02', dtype='datetime64[M]')

# %%
plt.plot(dd,A[15:,4])  ## Caramba professor essa é de quebrar a cabeça, muito legal shou de bola !!!!

# %% [markdown]
# # 4) Utilize os dados do INMET de uma estação convencional (Caxias do Sul-RS)

# %% [markdown]
#  # a. Calcule a média mensal climatológica da temperatura
#  # b. Compare a temperatura mensal de um ano (ex: 2016) com a média climatológica
#  # c. Calcule a perda de dados para cada mês

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from numpy import genfromtxt
from matplotlib import cm

# %%
uri='https://raw.githubusercontent.com/reginaldotiete/Dados_CDM/main/Reginaldo/CDM/master/CaxiasSulDiaFiltro2.txt'

# %%
df = pd.read_csv(uri,header=0); # o comando pd.read_ já tranforma em dataframe

# %%
df.info() #Informações básicas
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21641 entries, 0 to 21640
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID            21641 non-null  int64
#  1   ano           19452 non-null  float64
#  2   mes           19452 non-null  float64
#  3   dia           19452 non-null  float64
#  4   Precipitacao  21641 non-null  float64
#  5   TempMedia     16980 non-null  float64
#  6   TempMaxima    18925 non-null  float64
#  7   TempMinima    19309 non-null  float64
#  8   URMedia       14934 non-null  float64
# dtypes: float64(8), int64(1)
# memory usage: 1.5 MB

# %%
df.dtypes
# Out:
# ID                int64
# ano             float64
# mes             float64
# dia             float64
# Precipitacao    float64
# TempMedia       float64
# TempMaxima      float64
# TempMinima      float64
# URMedia         float64
# dtype: object

# %%
df.describe #Calcula a estatística básica: média, max, min, desvio, total
# Out:
# <bound method NDFrame.describe of           ID     ano  mes   dia  ...  TempMedia  TempMaxima  TempMinima  URMedia
# 0          0  1961.0  1.0   1.0  ...      22.16        27.0        17.4    80.00
# 1          1  1961.0  1.0   2.0  ...      24.00        31.2        18.2    66.25
# 2          2  1961.0  1.0   3.0  ...      21.88        28.6        19.6    84.25
# 3          3  1961.0  1.0   4.0  ...      18.40        24.8        15.4    83.00
# 4          4  1961.0  1.0   5.0  ...      21.48        28.2        15.6    73.50
# ...      ...     ...  ...   ...  ...        ...         ...         ...      ...
# 21636  21636  2020.0  3.0  28.0  ...        NaN        28.8        17.2    59.00
# 21637  21637  2020.0  3.0  29.0  ...        NaN        25.6        19.4    86.00
# 21638  21638  2020.0  3.0  30.0  ...        NaN        28.8        18.2    74.00
# 21639  21639  2020.0  3.0  31.0  ...        NaN        28.4        20.2    80.00
# ...

# %%
df.shape
# Out:
# (21641, 9)

# %%
df.head()
# Out:
#    ID     ano  mes  dia  ...  TempMedia  TempMaxima  TempMinima  URMedia
# 0   0  1961.0  1.0  1.0  ...      22.16        27.0        17.4    80.00
# 1   1  1961.0  1.0  2.0  ...      24.00        31.2        18.2    66.25
# 2   2  1961.0  1.0  3.0  ...      21.88        28.6        19.6    84.25
# 3   3  1961.0  1.0  4.0  ...      18.40        24.8        15.4    83.00
# 4   4  1961.0  1.0  5.0  ...      21.48        28.2        15.6    73.50
#
# [5 rows x 9 columns]

# %%
df = pd.read_csv(uri,header=0); # o comando pd.read_ já tranforma em dataframe

# %%
df.columns=['ID','ano','mes','dia','Precipitacao','TempMedia','TempMaxima','TempMinima','URMedia']

# %%
df
# Out:
#           ID     ano  mes   dia  ...  TempMedia  TempMaxima  TempMinima  URMedia
# 0          0  1961.0  1.0   1.0  ...      22.16        27.0        17.4    80.00
# 1          1  1961.0  1.0   2.0  ...      24.00        31.2        18.2    66.25
# 2          2  1961.0  1.0   3.0  ...      21.88        28.6        19.6    84.25
# 3          3  1961.0  1.0   4.0  ...      18.40        24.8        15.4    83.00
# 4          4  1961.0  1.0   5.0  ...      21.48        28.2        15.6    73.50
# ...      ...     ...  ...   ...  ...        ...         ...         ...      ...
# 21636  21636  2020.0  3.0  28.0  ...        NaN        28.8        17.2    59.00
# 21637  21637  2020.0  3.0  29.0  ...        NaN        25.6        19.4    86.00
# 21638  21638  2020.0  3.0  30.0  ...        NaN        28.8        18.2    74.00
# 21639  21639  2020.0  3.0  31.0  ...        NaN        28.4        20.2    80.00
# 21640  21640  2020.0  4.0   1.0  ...        NaN        29.4        18.6    75.00
#
# ...

# %%
df.head()
# Out:
#    ID     ano  mes  dia  ...  TempMedia  TempMaxima  TempMinima  URMedia
# 0   0  1961.0  1.0  1.0  ...      22.16        27.0        17.4    80.00
# 1   1  1961.0  1.0  2.0  ...      24.00        31.2        18.2    66.25
# 2   2  1961.0  1.0  3.0  ...      21.88        28.6        19.6    84.25
# 3   3  1961.0  1.0  4.0  ...      18.40        24.8        15.4    83.00
# 4   4  1961.0  1.0  5.0  ...      21.48        28.2        15.6    73.50
#
# [5 rows x 9 columns]

# %%
plt.plot(df['TempMedia']), df['ano']
# Out:
# ([<matplotlib.lines.Line2D at 0x7fc8d3827e10>], 0        1961.0
#  1        1961.0
#  2        1961.0
#  3        1961.0
#  4        1961.0
#            ...
#  21636    2020.0
#  21637    2020.0
#  21638    2020.0
#  21639    2020.0
#  21640    2020.0
#  Name: ano, Length: 21641, dtype: float64)

# %%
df=df.sort_index(axis=0, ascending=True)

# %%
df
# Out:
#           ID     ano  mes   dia  ...  TempMedia  TempMaxima  TempMinima  URMedia
# 0          0  1961.0  1.0   1.0  ...      22.16        27.0        17.4    80.00
# 1          1  1961.0  1.0   2.0  ...      24.00        31.2        18.2    66.25
# 2          2  1961.0  1.0   3.0  ...      21.88        28.6        19.6    84.25
# 3          3  1961.0  1.0   4.0  ...      18.40        24.8        15.4    83.00
# 4          4  1961.0  1.0   5.0  ...      21.48        28.2        15.6    73.50
# ...      ...     ...  ...   ...  ...        ...         ...         ...      ...
# 21636  21636  2020.0  3.0  28.0  ...        NaN        28.8        17.2    59.00
# 21637  21637  2020.0  3.0  29.0  ...        NaN        25.6        19.4    86.00
# 21638  21638  2020.0  3.0  30.0  ...        NaN        28.8        18.2    74.00
# 21639  21639  2020.0  3.0  31.0  ...        NaN        28.4        20.2    80.00
# 21640  21640  2020.0  4.0   1.0  ...        NaN        29.4        18.6    75.00
#
# ...

# %%
df = pd.read_csv(uri,header=0);

# %%
df
# Out:
#           ID     ano  mes   dia  ...  TempMedia  TempMaxima  TempMinima  URMedia
# 0          0  1961.0  1.0   1.0  ...      22.16        27.0        17.4    80.00
# 1          1  1961.0  1.0   2.0  ...      24.00        31.2        18.2    66.25
# 2          2  1961.0  1.0   3.0  ...      21.88        28.6        19.6    84.25
# 3          3  1961.0  1.0   4.0  ...      18.40        24.8        15.4    83.00
# 4          4  1961.0  1.0   5.0  ...      21.48        28.2        15.6    73.50
# ...      ...     ...  ...   ...  ...        ...         ...         ...      ...
# 21636  21636  2020.0  3.0  28.0  ...        NaN        28.8        17.2    59.00
# 21637  21637  2020.0  3.0  29.0  ...        NaN        25.6        19.4    86.00
# 21638  21638  2020.0  3.0  30.0  ...        NaN        28.8        18.2    74.00
# 21639  21639  2020.0  3.0  31.0  ...        NaN        28.4        20.2    80.00
# 21640  21640  2020.0  4.0   1.0  ...        NaN        29.4        18.6    75.00
#
# ...

# %%
df=pd.read_csv(uri,skiprows=0)

# %%
df.dtypes
# Out:
# ID                int64
# ano             float64
# mes             float64
# dia             float64
# Precipitacao    float64
# TempMedia       float64
# TempMaxima      float64
# TempMinima      float64
# URMedia         float64
# dtype: object

# %%
df=df.replace('-',np.nan)

# %%
df
# Out:
#           ID     ano  mes   dia  ...  TempMedia  TempMaxima  TempMinima  URMedia
# 0          0  1961.0  1.0   1.0  ...      22.16        27.0        17.4    80.00
# 1          1  1961.0  1.0   2.0  ...      24.00        31.2        18.2    66.25
# 2          2  1961.0  1.0   3.0  ...      21.88        28.6        19.6    84.25
# 3          3  1961.0  1.0   4.0  ...      18.40        24.8        15.4    83.00
# 4          4  1961.0  1.0   5.0  ...      21.48        28.2        15.6    73.50
# ...      ...     ...  ...   ...  ...        ...         ...         ...      ...
# 21636  21636  2020.0  3.0  28.0  ...        NaN        28.8        17.2    59.00
# 21637  21637  2020.0  3.0  29.0  ...        NaN        25.6        19.4    86.00
# 21638  21638  2020.0  3.0  30.0  ...        NaN        28.8        18.2    74.00
# 21639  21639  2020.0  3.0  31.0  ...        NaN        28.4        20.2    80.00
# 21640  21640  2020.0  4.0   1.0  ...        NaN        29.4        18.6    75.00
#
# ...

# %%
plt.plot(df['ID'])
plt.plot(df['TempMaxima'])

# %%
df.columns
# Out:
# Index(['ID', 'ano', 'mes', 'dia', 'Precipitacao', 'TempMedia', 'TempMaxima',
#        'TempMinima', 'URMedia'],
#       dtype='object')

# %%
plt.scatter(df['TempMedia'],df['mes']),df['ano'],df['dia'],df['ID'].T
# Out:
# (<matplotlib.collections.PathCollection at 0x7fc8d38527d0>, 0        1961.0
#  1        1961.0
#  2        1961.0
#  3        1961.0
#  4        1961.0
#            ...
#  21636    2020.0
#  21637    2020.0
#  21638    2020.0
#  21639    2020.0
#  21640    2020.0
#  Name: ano, Length: 21641, dtype: float64, 0         1.0
#  1         2.0
#  2         3.0
#  3         4.0
#  4         5.0
#           ...
#  21636    28.0
#  21637    29.0
#  21638    30.0
#  21639    31.0
#  21640     1.0
#  Name: dia, Length: 21641, dtype: float64, 0            0
#  1            1
#  2            2
#  3            3
#  4            4
#           ...
#  21636    21636
#  21637    21637
#  21638    21638
#  21639    21639
#  21640    21640
#  Name: ID, Length: 21641, dtype: int64)

# %%
plt.plot(df['TempMedia']),df['mes']
# Out:
# ([<matplotlib.lines.Line2D at 0x7fc8d3649dd0>], 0        1.0
#  1        1.0
#  2        1.0
#  3        1.0
#  4        1.0
#          ...
#  21636    3.0
#  21637    3.0
#  21638    3.0
#  21639    3.0
#  21640    4.0
#  Name: mes, Length: 21641, dtype: float64)

# %%
a=df.to_numpy()

# %%
#df.T
# Out:
#                 0        1        2      ...    21638    21639    21640
# ID               0.00     1.00     2.00  ...  21638.0  21639.0  21640.0
# ano           1961.00  1961.00  1961.00  ...   2020.0   2020.0   2020.0
# mes              1.00     1.00     1.00  ...      3.0      3.0      4.0
# dia              1.00     2.00     3.00  ...     30.0     31.0      1.0
# Precipitacao     0.00     0.80     0.00  ...      5.3      0.0      0.3
# TempMedia       22.16    24.00    21.88  ...      NaN      NaN      NaN
# TempMaxima      27.00    31.20    28.60  ...     28.8     28.4     29.4
# TempMinima      17.40    18.20    19.60  ...     18.2     20.2     18.6
# URMedia         80.00    66.25    84.25  ...     74.0     80.0     75.0
#
# [9 rows x 21641 columns]

# %%
plt.plot(df['Precipitacao'])

# %%
plt.plot(df['TempMedia'])

# %%
plt.plot(df['TempMedia'].mean())
plt.plot(df['mes'])
#plt.plot(df['ano'])
plt.xticks(rotation=90)
# Out:
# (array([-5000.,     0.,  5000., 10000., 15000., 20000., 25000.]),
#  <a list of 7 Text major ticklabel objects>)

# %%
df=df.groupby(level=[0]).mean()

# %%
np.round(df,1)
# Out:
#           ID     ano  mes   dia  ...  TempMedia  TempMaxima  TempMinima  URMedia
# 0          0  1961.0  1.0   1.0  ...       22.2        27.0        17.4     80.0
# 1          1  1961.0  1.0   2.0  ...       24.0        31.2        18.2     66.2
# 2          2  1961.0  1.0   3.0  ...       21.9        28.6        19.6     84.2
# 3          3  1961.0  1.0   4.0  ...       18.4        24.8        15.4     83.0
# 4          4  1961.0  1.0   5.0  ...       21.5        28.2        15.6     73.5
# ...      ...     ...  ...   ...  ...        ...         ...         ...      ...
# 21636  21636  2020.0  3.0  28.0  ...        NaN        28.8        17.2     59.0
# 21637  21637  2020.0  3.0  29.0  ...        NaN        25.6        19.4     86.0
# 21638  21638  2020.0  3.0  30.0  ...        NaN        28.8        18.2     74.0
# 21639  21639  2020.0  3.0  31.0  ...        NaN        28.4        20.2     80.0
# 21640  21640  2020.0  4.0   1.0  ...        NaN        29.4        18.6     75.0
#
# ...

# %%
df.columns
# Out:
# Index(['ID', 'ano', 'mes', 'dia', 'Precipitacao', 'TempMedia', 'TempMaxima',
#        'TempMinima', 'URMedia'],
#       dtype='object')

# %%
df.index.duplicated(keep='last')
# Out:
# array([False, False, False, ..., False, False, False])

# %%
plt.plot(df['TempMaxima'])

# %%
id=pd.DatetimeIndex(df)

# %%
df
# Out:
#           ID     ano  mes   dia  ...  TempMedia  TempMaxima  TempMinima  URMedia
# 0          0  1961.0  1.0   1.0  ...      22.16        27.0        17.4    80.00
# 1          1  1961.0  1.0   2.0  ...      24.00        31.2        18.2    66.25
# 2          2  1961.0  1.0   3.0  ...      21.88        28.6        19.6    84.25
# 3          3  1961.0  1.0   4.0  ...      18.40        24.8        15.4    83.00
# 4          4  1961.0  1.0   5.0  ...      21.48        28.2        15.6    73.50
# ...      ...     ...  ...   ...  ...        ...         ...         ...      ...
# 21636  21636  2020.0  3.0  28.0  ...        NaN        28.8        17.2    59.00
# 21637  21637  2020.0  3.0  29.0  ...        NaN        25.6        19.4    86.00
# 21638  21638  2020.0  3.0  30.0  ...        NaN        28.8        18.2    74.00
# 21639  21639  2020.0  3.0  31.0  ...        NaN        28.4        20.2    80.00
# 21640  21640  2020.0  4.0   1.0  ...        NaN        29.4        18.6    75.00
#
# ...

# %%
#df.columns=['ID', 'ano', 'mes', 'dia', 'Precipitacao', 'TempMedia', 'TempMaxima', 'TempMinima', 'URMedia']

# %%
flag=pd.DataFrame(df.count()+df.isna().sum(),columns=['total']) #Total de dados do dataframe

# %%
flag['validos']=flag['total']-flag.iloc[:,2:].sum(axis=1) #Dados Válidos

# %%
df=df.fillna(0)

# %%
df=df.fillna(method='bfill')

# %%
df=df.interpolate(method='time')

# %%
plt.plot(df['TempMedia'].mean())
plt.plot(df[9:21640])

# %%
df.sort_index()
# Out:
#           ID     ano  mes   dia  ...  TempMedia  TempMaxima  TempMinima  URMedia
# 0          0  1961.0  1.0   1.0  ...      22.16        27.0        17.4    80.00
# 1          1  1961.0  1.0   2.0  ...      24.00        31.2        18.2    66.25
# 2          2  1961.0  1.0   3.0  ...      21.88        28.6        19.6    84.25
# 3          3  1961.0  1.0   4.0  ...      18.40        24.8        15.4    83.00
# 4          4  1961.0  1.0   5.0  ...      21.48        28.2        15.6    73.50
# ...      ...     ...  ...   ...  ...        ...         ...         ...      ...
# 21636  21636  2020.0  3.0  28.0  ...       0.00        28.8        17.2    59.00
# 21637  21637  2020.0  3.0  29.0  ...       0.00        25.6        19.4    86.00
# 21638  21638  2020.0  3.0  30.0  ...       0.00        28.8        18.2    74.00
# 21639  21639  2020.0  3.0  31.0  ...       0.00        28.4        20.2    80.00
# 21640  21640  2020.0  4.0   1.0  ...       0.00        29.4        18.6    75.00
#
# ...

# %%
df
# Out:
#           ID     ano  mes   dia  ...  TempMedia  TempMaxima  TempMinima  URMedia
# 0          0  1961.0  1.0   1.0  ...      22.16        27.0        17.4    80.00
# 1          1  1961.0  1.0   2.0  ...      24.00        31.2        18.2    66.25
# 2          2  1961.0  1.0   3.0  ...      21.88        28.6        19.6    84.25
# 3          3  1961.0  1.0   4.0  ...      18.40        24.8        15.4    83.00
# 4          4  1961.0  1.0   5.0  ...      21.48        28.2        15.6    73.50
# ...      ...     ...  ...   ...  ...        ...         ...         ...      ...
# 21636  21636  2020.0  3.0  28.0  ...       0.00        28.8        17.2    59.00
# 21637  21637  2020.0  3.0  29.0  ...       0.00        25.6        19.4    86.00
# 21638  21638  2020.0  3.0  30.0  ...       0.00        28.8        18.2    74.00
# 21639  21639  2020.0  3.0  31.0  ...       0.00        28.4        20.2    80.00
# 21640  21640  2020.0  4.0   1.0  ...       0.00        29.4        18.6    75.00
#
# ...

# %%
#df.pivot_table(index=['ano','mes','dia'])
# Out:
#                  Precipitacao  TempMaxima  TempMedia  TempMinima  URMedia
# ano    mes dia
# 0.0    0.0 0.0       0.056464    0.186067       0.00    0.113705     0.00
# 1961.0 1.0 1.0       0.000000   27.000000      22.16   17.400000    80.00
#            2.0       0.800000   31.200000      24.00   18.200000    66.25
#            3.0       0.000000   28.600000      21.88   19.600000    84.25
#            4.0      58.400000   24.800000      18.40   15.400000    83.00
# ...                       ...         ...        ...         ...      ...
# 2020.0 3.0 28.0      0.000000   28.800000       0.00   17.200000    59.00
#            29.0      0.200000   25.600000       0.00   19.400000    86.00
#            30.0      5.300000   28.800000       0.00   18.200000    74.00
#            31.0      0.000000   28.400000       0.00   20.200000    80.00
#        4.0 1.0       0.300000   29.400000       0.00   18.600000    75.00
#
# [19453 rows x 5 columns]

# %%
df
# Out:
#           ID     ano  mes   dia  ...  TempMedia  TempMaxima  TempMinima  URMedia
# 0          0  1961.0  1.0   1.0  ...      22.16        27.0        17.4    80.00
# 1          1  1961.0  1.0   2.0  ...      24.00        31.2        18.2    66.25
# 2          2  1961.0  1.0   3.0  ...      21.88        28.6        19.6    84.25
# 3          3  1961.0  1.0   4.0  ...      18.40        24.8        15.4    83.00
# 4          4  1961.0  1.0   5.0  ...      21.48        28.2        15.6    73.50
# ...      ...     ...  ...   ...  ...        ...         ...         ...      ...
# 21636  21636  2020.0  3.0  28.0  ...       0.00        28.8        17.2    59.00
# 21637  21637  2020.0  3.0  29.0  ...       0.00        25.6        19.4    86.00
# 21638  21638  2020.0  3.0  30.0  ...       0.00        28.8        18.2    74.00
# 21639  21639  2020.0  3.0  31.0  ...       0.00        28.4        20.2    80.00
# 21640  21640  2020.0  4.0   1.0  ...       0.00        29.4        18.6    75.00
#
# ...

# %%
#df.apply(lambda x: pd.to_datetime(x,errors = 'coerce', format = '%Y-%m-%d'))
# Out:
#                                  ID  ...                       URMedia
# 0     1970-01-01 00:00:00.000000000  ... 1970-01-01 00:00:00.000000080
# 1     1970-01-01 00:00:00.000000001  ... 1970-01-01 00:00:00.000000066
# 2     1970-01-01 00:00:00.000000002  ... 1970-01-01 00:00:00.000000084
# 3     1970-01-01 00:00:00.000000003  ... 1970-01-01 00:00:00.000000083
# 4     1970-01-01 00:00:00.000000004  ... 1970-01-01 00:00:00.000000073
# ...                             ...  ...                           ...
# 21636 1970-01-01 00:00:00.000021636  ... 1970-01-01 00:00:00.000000059
# 21637 1970-01-01 00:00:00.000021637  ... 1970-01-01 00:00:00.000000086
# 21638 1970-01-01 00:00:00.000021638  ... 1970-01-01 00:00:00.000000074
# 21639 1970-01-01 00:00:00.000021639  ... 1970-01-01 00:00:00.000000080
# 21640 1970-01-01 00:00:00.000021640  ... 1970-01-01 00:00:00.000000075
#
# [21641 rows x 9 columns]

# %%
df[df=='NAN']=np.nan

# %%
#df.sort_index(axis=0, decending=False)
#df.T

# %%
#df=df.drop(['ano','mes','dia'],axis=1) # exclui colunas
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-881-53b65e86a336> in <module>()
# ----> 1 df=df.drop(['ano','mes','dia'],axis=1) # exclui colunas
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4172             level=level,
#    4173             inplace=inplace,
# -> 4174             errors=errors,
#    4175         )
#    4176
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3887         for axis, labels in axes.items():
#    3888             if labels is not None:
# -> 3889                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3890
#    3891         if inplace:
#
# ...

# %%
df
# Out:
#           ID     ano  mes   dia  ...  TempMedia  TempMaxima  TempMinima  URMedia
# 0          0  1961.0  1.0   1.0  ...      22.16        27.0        17.4    80.00
# 1          1  1961.0  1.0   2.0  ...      24.00        31.2        18.2    66.25
# 2          2  1961.0  1.0   3.0  ...      21.88        28.6        19.6    84.25
# 3          3  1961.0  1.0   4.0  ...      18.40        24.8        15.4    83.00
# 4          4  1961.0  1.0   5.0  ...      21.48        28.2        15.6    73.50
# ...      ...     ...  ...   ...  ...        ...         ...         ...      ...
# 21636  21636  2020.0  3.0  28.0  ...       0.00        28.8        17.2    59.00
# 21637  21637  2020.0  3.0  29.0  ...       0.00        25.6        19.4    86.00
# 21638  21638  2020.0  3.0  30.0  ...       0.00        28.8        18.2    74.00
# 21639  21639  2020.0  3.0  31.0  ...       0.00        28.4        20.2    80.00
# 21640  21640  2020.0  4.0   1.0  ...       0.00        29.4        18.6    75.00
#
# ...

# %%
df2=df.copy()

# %%
df2
# Out:
#           ID     ano  mes   dia  ...  TempMedia  TempMaxima  TempMinima  URMedia
# 0          0  1961.0  1.0   1.0  ...      22.16        27.0        17.4    80.00
# 1          1  1961.0  1.0   2.0  ...      24.00        31.2        18.2    66.25
# 2          2  1961.0  1.0   3.0  ...      21.88        28.6        19.6    84.25
# 3          3  1961.0  1.0   4.0  ...      18.40        24.8        15.4    83.00
# 4          4  1961.0  1.0   5.0  ...      21.48        28.2        15.6    73.50
# ...      ...     ...  ...   ...  ...        ...         ...         ...      ...
# 21636  21636  2020.0  3.0  28.0  ...       0.00        28.8        17.2    59.00
# 21637  21637  2020.0  3.0  29.0  ...       0.00        25.6        19.4    86.00
# 21638  21638  2020.0  3.0  30.0  ...       0.00        28.8        18.2    74.00
# 21639  21639  2020.0  3.0  31.0  ...       0.00        28.4        20.2    80.00
# 21640  21640  2020.0  4.0   1.0  ...       0.00        29.4        18.6    75.00
#
# ...

# %%
df2.dropna(how='all') # exclui linhas onde todas as linhas são NaN
# Out:
#           ID     ano  mes   dia  ...  TempMedia  TempMaxima  TempMinima  URMedia
# 0          0  1961.0  1.0   1.0  ...      22.16        27.0        17.4    80.00
# 1          1  1961.0  1.0   2.0  ...      24.00        31.2        18.2    66.25
# 2          2  1961.0  1.0   3.0  ...      21.88        28.6        19.6    84.25
# 3          3  1961.0  1.0   4.0  ...      18.40        24.8        15.4    83.00
# 4          4  1961.0  1.0   5.0  ...      21.48        28.2        15.6    73.50
# ...      ...     ...  ...   ...  ...        ...         ...         ...      ...
# 21636  21636  2020.0  3.0  28.0  ...       0.00        28.8        17.2    59.00
# 21637  21637  2020.0  3.0  29.0  ...       0.00        25.6        19.4    86.00
# 21638  21638  2020.0  3.0  30.0  ...       0.00        28.8        18.2    74.00
# 21639  21639  2020.0  3.0  31.0  ...       0.00        28.4        20.2    80.00
# 21640  21640  2020.0  4.0   1.0  ...       0.00        29.4        18.6    75.00
#
# ...

# %%
df2
# Out:
#           ID     ano  mes   dia  ...  TempMedia  TempMaxima  TempMinima  URMedia
# 0          0  1961.0  1.0   1.0  ...      22.16        27.0        17.4    80.00
# 1          1  1961.0  1.0   2.0  ...      24.00        31.2        18.2    66.25
# 2          2  1961.0  1.0   3.0  ...      21.88        28.6        19.6    84.25
# 3          3  1961.0  1.0   4.0  ...      18.40        24.8        15.4    83.00
# 4          4  1961.0  1.0   5.0  ...      21.48        28.2        15.6    73.50
# ...      ...     ...  ...   ...  ...        ...         ...         ...      ...
# 21636  21636  2020.0  3.0  28.0  ...       0.00        28.8        17.2    59.00
# 21637  21637  2020.0  3.0  29.0  ...       0.00        25.6        19.4    86.00
# 21638  21638  2020.0  3.0  30.0  ...       0.00        28.8        18.2    74.00
# 21639  21639  2020.0  3.0  31.0  ...       0.00        28.4        20.2    80.00
# 21640  21640  2020.0  4.0   1.0  ...       0.00        29.4        18.6    75.00
#
# ...

# %%
df2.dropna(how='all') # exclui linhas onde todas as linhas são NaN
# Out:
#           ID     ano  mes   dia  ...  TempMedia  TempMaxima  TempMinima  URMedia
# 0          0  1961.0  1.0   1.0  ...      22.16        27.0        17.4    80.00
# 1          1  1961.0  1.0   2.0  ...      24.00        31.2        18.2    66.25
# 2          2  1961.0  1.0   3.0  ...      21.88        28.6        19.6    84.25
# 3          3  1961.0  1.0   4.0  ...      18.40        24.8        15.4    83.00
# 4          4  1961.0  1.0   5.0  ...      21.48        28.2        15.6    73.50
# ...      ...     ...  ...   ...  ...        ...         ...         ...      ...
# 21636  21636  2020.0  3.0  28.0  ...       0.00        28.8        17.2    59.00
# 21637  21637  2020.0  3.0  29.0  ...       0.00        25.6        19.4    86.00
# 21638  21638  2020.0  3.0  30.0  ...       0.00        28.8        18.2    74.00
# 21639  21639  2020.0  3.0  31.0  ...       0.00        28.4        20.2    80.00
# 21640  21640  2020.0  4.0   1.0  ...       0.00        29.4        18.6    75.00
#
# ...

# %%
plt.plot(df2['TempMedia'])

# %%
plt.plot(df2['TempMaxima'])

# %%
plt.plot(df2['TempMinima'])

# %%
df2
# Out:
#           ID     ano  mes   dia  ...  TempMedia  TempMaxima  TempMinima  URMedia
# 0          0  1961.0  1.0   1.0  ...      22.16        27.0        17.4    80.00
# 1          1  1961.0  1.0   2.0  ...      24.00        31.2        18.2    66.25
# 2          2  1961.0  1.0   3.0  ...      21.88        28.6        19.6    84.25
# 3          3  1961.0  1.0   4.0  ...      18.40        24.8        15.4    83.00
# 4          4  1961.0  1.0   5.0  ...      21.48        28.2        15.6    73.50
# ...      ...     ...  ...   ...  ...        ...         ...         ...      ...
# 21636  21636  2020.0  3.0  28.0  ...       0.00        28.8        17.2    59.00
# 21637  21637  2020.0  3.0  29.0  ...       0.00        25.6        19.4    86.00
# 21638  21638  2020.0  3.0  30.0  ...       0.00        28.8        18.2    74.00
# 21639  21639  2020.0  3.0  31.0  ...       0.00        28.4        20.2    80.00
# 21640  21640  2020.0  4.0   1.0  ...       0.00        29.4        18.6    75.00
#
# ...

# %%
df
# Out:
#           ID     ano  mes   dia  ...  TempMedia  TempMaxima  TempMinima  URMedia
# 0          0  1961.0  1.0   1.0  ...      22.16        27.0        17.4    80.00
# 1          1  1961.0  1.0   2.0  ...      24.00        31.2        18.2    66.25
# 2          2  1961.0  1.0   3.0  ...      21.88        28.6        19.6    84.25
# 3          3  1961.0  1.0   4.0  ...      18.40        24.8        15.4    83.00
# 4          4  1961.0  1.0   5.0  ...      21.48        28.2        15.6    73.50
# ...      ...     ...  ...   ...  ...        ...         ...         ...      ...
# 21636  21636  2020.0  3.0  28.0  ...       0.00        28.8        17.2    59.00
# 21637  21637  2020.0  3.0  29.0  ...       0.00        25.6        19.4    86.00
# 21638  21638  2020.0  3.0  30.0  ...       0.00        28.8        18.2    74.00
# 21639  21639  2020.0  3.0  31.0  ...       0.00        28.4        20.2    80.00
# 21640  21640  2020.0  4.0   1.0  ...       0.00        29.4        18.6    75.00
#
# ...

# %%
plt.plot(df['TempMedia'])

# %%
df
# Out:
#           ID     ano  mes   dia  ...  TempMedia  TempMaxima  TempMinima  URMedia
# 0          0  1961.0  1.0   1.0  ...      22.16        27.0        17.4    80.00
# 1          1  1961.0  1.0   2.0  ...      24.00        31.2        18.2    66.25
# 2          2  1961.0  1.0   3.0  ...      21.88        28.6        19.6    84.25
# 3          3  1961.0  1.0   4.0  ...      18.40        24.8        15.4    83.00
# 4          4  1961.0  1.0   5.0  ...      21.48        28.2        15.6    73.50
# ...      ...     ...  ...   ...  ...        ...         ...         ...      ...
# 21636  21636  2020.0  3.0  28.0  ...       0.00        28.8        17.2    59.00
# 21637  21637  2020.0  3.0  29.0  ...       0.00        25.6        19.4    86.00
# 21638  21638  2020.0  3.0  30.0  ...       0.00        28.8        18.2    74.00
# 21639  21639  2020.0  3.0  31.0  ...       0.00        28.4        20.2    80.00
# 21640  21640  2020.0  4.0   1.0  ...       0.00        29.4        18.6    75.00
#
# ...

# %%
df
# Out:
#           ano  mes   dia  ...  TempMaxima  TempMinima  URMedia
# 0      1961.0  1.0   1.0  ...        27.0        17.4    80.00
# 1      1961.0  1.0   2.0  ...        31.2        18.2    66.25
# 2      1961.0  1.0   3.0  ...        28.6        19.6    84.25
# 3      1961.0  1.0   4.0  ...        24.8        15.4    83.00
# 4      1961.0  1.0   5.0  ...        28.2        15.6    73.50
# ...       ...  ...   ...  ...         ...         ...      ...
# 21636  2020.0  3.0  28.0  ...        28.8        17.2    59.00
# 21637  2020.0  3.0  29.0  ...        25.6        19.4    86.00
# 21638  2020.0  3.0  30.0  ...        28.8        18.2    74.00
# 21639  2020.0  3.0  31.0  ...        28.4        20.2    80.00
# 21640  2020.0  4.0   1.0  ...        29.4        18.6    75.00
#
# [21641 rows x 8 columns]

# %%
df.hist('Precipitacao')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc8d232fd10>]],
#       dtype=object)

# %%
df.hist('TempMedia')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc8d2350950>]],
#       dtype=object)

# %%
df.hist('TempMaxima')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc8d222f390>]],
#       dtype=object)

# %%
df.hist('TempMinima')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc8d224ae90>]],
#       dtype=object)

# %%
df.hist('URMedia')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc8d226edd0>]],
#       dtype=object)

# %%
#    #função definda (coverte temperatura Celsius em kelvin)

# %%
#df['TempMaxima']=df['TempMinima'].apply(f) # aplica uma função em um Dataframe

# %%
df['TempMaxima']
# Out:
# 0        27.0
# 1        31.2
# 2        28.6
# 3        24.8
# 4        28.2
#          ...
# 21636    28.8
# 21637    25.6
# 21638    28.8
# 21639    28.4
# 21640    29.4
# Name: TempMaxima, Length: 21641, dtype: float64

# %%
f=lambda x:x+273.15

# %%
df['TempMinima'].apply(f)
# Out:
# 0        290.55
# 1        291.35
# 2        292.75
# 3        288.55
# 4        288.75
#           ...
# 21636    290.35
# 21637    292.55
# 21638    291.35
# 21639    293.35
# 21640    291.75
# Name: TempMinima, Length: 21641, dtype: float64

# %%
df['TempMinima']
# Out:
# 0        17.4
# 1        18.2
# 2        19.6
# 3        15.4
# 4        15.6
#          ...
# 21636    17.2
# 21637    19.4
# 21638    18.2
# 21639    20.2
# 21640    18.6
# Name: TempMinima, Length: 21641, dtype: float64

# %%
df.drop(df.index[1:4])
# Out:
#           ano  mes   dia  ...  TempMaxima  TempMinima  URMedia
# 0      1961.0  1.0   1.0  ...        27.0        17.4    80.00
# 4      1961.0  1.0   5.0  ...        28.2        15.6    73.50
# 5      1961.0  1.0   6.0  ...        21.8        17.2    95.75
# 6      1961.0  1.0   7.0  ...        24.6        10.6    75.00
# 7      1961.0  1.0   8.0  ...        29.8        14.4    64.50
# ...       ...  ...   ...  ...         ...         ...      ...
# 21636  2020.0  3.0  28.0  ...        28.8        17.2    59.00
# 21637  2020.0  3.0  29.0  ...        25.6        19.4    86.00
# 21638  2020.0  3.0  30.0  ...        28.8        18.2    74.00
# 21639  2020.0  3.0  31.0  ...        28.4        20.2    80.00
# 21640  2020.0  4.0   1.0  ...        29.4        18.6    75.00
#
# [21638 rows x 8 columns]

# %%
df2=df.iloc[0:30,1:7]

df2
# Out:
#     mes   dia  Precipitacao  TempMedia  TempMaxima  TempMinima
# 0   1.0   1.0           0.0      22.16        27.0        17.4
# 1   1.0   2.0           0.8      24.00        31.2        18.2
# 2   1.0   3.0           0.0      21.88        28.6        19.6
# 3   1.0   4.0          58.4      18.40        24.8        15.4
# 4   1.0   5.0           0.1      21.48        28.2        15.6
# 5   1.0   6.0          47.6      18.36        21.8        17.2
# 6   1.0   7.0          11.1      17.56        24.6        10.6
# 7   1.0   8.0           0.0      21.60        29.8        14.4
# 8   1.0   9.0           0.0      23.48        31.2        17.6
# 9   1.0  10.0           0.0      20.72        24.2        18.2
# 10  1.0  11.0          13.6      19.98        25.2        16.7
# 11  1.0  12.0           0.0      23.04        30.4        16.2
# 12  1.0  13.0           0.0      24.26        30.2        18.5
# 13  1.0  14.0           0.0      24.76        30.0        19.8
# ...

# %%
plt.plot(df2['TempMedia'])

# %%
plt.plot(df2['TempMaxima'])

# %%
plt.plot(df2['TempMinima'])

# %%
dtype='ID'

# %%
plt.plot(df2['TempMinima'])

# %%
df.T
# Out:
#                 0        1        2       3      ...   21637   21638   21639   21640
# ano           1961.00  1961.00  1961.00  1961.0  ...  2020.0  2020.0  2020.0  2020.0
# mes              1.00     1.00     1.00     1.0  ...     3.0     3.0     3.0     4.0
# dia              1.00     2.00     3.00     4.0  ...    29.0    30.0    31.0     1.0
# Precipitacao     0.00     0.80     0.00    58.4  ...     0.2     5.3     0.0     0.3
# TempMedia       22.16    24.00    21.88    18.4  ...     0.0     0.0     0.0     0.0
# TempMaxima      27.00    31.20    28.60    24.8  ...    25.6    28.8    28.4    29.4
# TempMinima      17.40    18.20    19.60    15.4  ...    19.4    18.2    20.2    18.6
# URMedia         80.00    66.25    84.25    83.0  ...    86.0    74.0    80.0    75.0
#
# [8 rows x 21641 columns]

# %%
df
# Out:
#           ano  mes   dia  ...  TempMaxima  TempMinima  URMedia
# 0      1961.0  1.0   1.0  ...        27.0        17.4    80.00
# 1      1961.0  1.0   2.0  ...        31.2        18.2    66.25
# 2      1961.0  1.0   3.0  ...        28.6        19.6    84.25
# 3      1961.0  1.0   4.0  ...        24.8        15.4    83.00
# 4      1961.0  1.0   5.0  ...        28.2        15.6    73.50
# ...       ...  ...   ...  ...         ...         ...      ...
# 21636  2020.0  3.0  28.0  ...        28.8        17.2    59.00
# 21637  2020.0  3.0  29.0  ...        25.6        19.4    86.00
# 21638  2020.0  3.0  30.0  ...        28.8        18.2    74.00
# 21639  2020.0  3.0  31.0  ...        28.4        20.2    80.00
# 21640  2020.0  4.0   1.0  ...        29.4        18.6    75.00
#
# [21641 rows x 8 columns]

# %% [markdown]
# # 5) Extra: Desafio baixar os dados de inmet e processar os dados a partir dos dados brutos
